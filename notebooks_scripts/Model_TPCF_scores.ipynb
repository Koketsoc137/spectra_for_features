# %%
import os
import sys
import pickle
import numpy as np
import pandas as pd

# allow importing the "backbone" package when the kernel's cwd is noteonooks/
sys.path.append(os.path.abspath(".."))

import backbone.custom_metrics.AstroMLmod3 as AstroMLmod
import backbone.custom_metrics.Intrinsic_dimension as id_module
from backbone.data_handle.Test import KNN_accuracy
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import davies_bouldin_score

# %% [markdown]
# # Test representations: TPCF & ID scores per epoch

# %%
n_epochs = 100

tpcf_scores = []
tpcf_std_scores = []
id_scores = []
cosine_sim_scores = []
cosine_sim_std_scores = []
anisotropy_scores = []
davies_bouldin_scores = []
knn_accuracy_scores = []
knn_accuracy_std_scores = []

for epoch in range(n_epochs):
    pkl_filename = f"../Plots/Test_representations_labels{epoch}.csv"
    with open(pkl_filename, 'rb') as file:
        test_rep = pickle.load(file)

    representations = np.array(test_rep[0])
    labels = test_rep[1]
    n = representations.shape[0]

    # TPCF_score bootstraps over subsamples and returns (mean, std)
    tpcf, tpcf_std = AstroMLmod.TPCF_score(representations, epoch=epoch)
    id_ = id_module.id_score(representations)
    db_score = davies_bouldin_score(representations, labels)
    knn_acc, knn_acc_std = KNN_accuracy(representations, labels)

    # average pairwise cosine similarity, excluding self-similarity on the diagonal
    cos_sim_matrix = cosine_similarity(representations)
    off_diag_mask = ~np.eye(n, dtype=bool)
    avg_cos_sim = cos_sim_matrix[off_diag_mask].mean()
    std_cos_sim = cos_sim_matrix[off_diag_mask].std()

    # anisotropy: fraction of variance explained by the top singular direction
    centered = representations - representations.mean(axis=0, keepdims=True)
    singular_values = np.linalg.svd(centered, compute_uv=False)
    explained_variance = (singular_values ** 2) / (n - 1)
    explained_variance_ratio = explained_variance / explained_variance.sum()
    anisotropy = explained_variance_ratio[0]

    tpcf_scores.append(tpcf)
    tpcf_std_scores.append(tpcf_std)
    id_scores.append(id_)
    cosine_sim_scores.append(avg_cos_sim)
    cosine_sim_std_scores.append(std_cos_sim)
    anisotropy_scores.append(anisotropy)
    davies_bouldin_scores.append(db_score)
    knn_accuracy_scores.append(knn_acc)
    knn_accuracy_std_scores.append(knn_acc_std)

    print(f"Epoch {epoch}: TPCF={tpcf:.4f}±{tpcf_std:.4f} ID={id_} CosineSim={avg_cos_sim:.4f}±{std_cos_sim:.4f} Anisotropy={anisotropy:.4f} DaviesBouldin={db_score:.4f} KNNAcc={knn_acc:.2f}±{knn_acc_std:.2f}")
# Out:
# Epoch 0: TPCF=568.2100±330.3700 ID=(np.float64(52.743260870074586), np.float64(1.6315948275090064)) CosineSim=0.1953±0.1200 Anisotropy=0.9690 DaviesBouldin=12.2427 KNNAcc=20.16±0.43
# Epoch 1: TPCF=6038.6600±1038.9900 ID=(np.float64(6.493028307663323), np.float64(0.25217636138031363)) CosineSim=0.8132±0.1050 Anisotropy=0.9935 DaviesBouldin=3.3405 KNNAcc=56.97±0.52
# Epoch 2: TPCF=9338.3400±3740.3200 ID=(np.float64(5.5994039291439455), np.float64(0.138678906053743)) CosineSim=0.7730±0.1009 Anisotropy=0.1940 DaviesBouldin=2.1090 KNNAcc=69.77±0.51
# Epoch 3: TPCF=5069.4100±1363.3600 ID=(np.float64(5.148119720458731), np.float64(0.21233200192308818)) CosineSim=0.7643±0.1002 Anisotropy=0.2050 DaviesBouldin=1.9558 KNNAcc=74.45±0.28
# Epoch 4: TPCF=6203.8800±2427.5500 ID=(np.float64(4.812330304736568), np.float64(0.08547200522589439)) CosineSim=0.7541±0.0996 Anisotropy=0.1975 DaviesBouldin=1.4743 KNNAcc=76.55±0.29
# Epoch 5: TPCF=5441.1700±1014.8400 ID=(np.float64(4.8671049555291885), np.float64(0.21872506863617283)) CosineSim=0.7473±0.1013 Anisotropy=0.1695 DaviesBouldin=1.4092 KNNAcc=78.64±0.33
# Epoch 6: TPCF=8186.5700±1896.6100 ID=(np.float64(4.598119047683098), np.float64(0.17297815176607276)) CosineSim=0.7427±0.1003 Anisotropy=0.1686 DaviesBouldin=1.3750 KNNAcc=79.85±0.36
# Epoch 7: TPCF=5104.4700±1343.5200 ID=(np.float64(4.302252829760585), np.float64(0.234861843901119)) CosineSim=0.7304±0.1048 Anisotropy=0.2143 DaviesBouldin=1.3743 KNNAcc=80.19±0.16
# Epoch 8: TPCF=5089.6900±2489.4900 ID=(np.float64(4.456355466921264), np.float64(0.09612696100739568)) CosineSim=0.7275±0.1039 Anisotropy=0.1776 DaviesBouldin=1.3617 KNNAcc=80.31±0.40
# Epoch 9: TPCF=4929.8600±1468.6300 ID=(np.float64(4.246084780099199), np.float64(0.06859708714524886)) CosineSim=0.7266±0.1053 Anisotropy=0.1783 DaviesBouldin=1.3237 KNNAcc=80.79±0.16
# Epoch 10: TPCF=5551.3000±1296.0300 ID=(np.float64(4.166451820825866), np.float64(0.15577074744381325)) CosineSim=0.7321±0.1041 Anisotropy=0.1986 DaviesBouldin=1.4333 KNNAcc=78.99±0.27
# Epoch 11: TPCF=6827.6300±3786.7300 ID=(np.float64(3.989343263756889), np.float64(0.09907549029679463)) CosineSim=0.7105±0.1127 Anisotropy=0.1896 DaviesBouldin=1.3490 KNNAcc=80.96±0.42
# Epoch 12: TPCF=7273.8000±2575.1700 ID=(np.float64(3.789183345283098), np.float64(0.11256563848604946)) CosineSim=0.7133±0.1096 Anisotropy=0.1810 DaviesBouldin=1.2613 KNNAcc=81.94±0.26
# Epoch 13: TPCF=6202.6400±1343.3500 ID=(np.float64(3.9856085785473008), np.float64(0.14264610897189936)) CosineSim=0.7083±0.1128 Anisotropy=0.1747 DaviesBouldin=1.4131 KNNAcc=81.37±0.30
# Epoch 14: TPCF=3883.0700±1057.3300 ID=(np.float64(3.695396107681657), np.float64(0.13970233896861017)) CosineSim=0.7058±0.1113 Anisotropy=0.2041 DaviesBouldin=1.2875 KNNAcc=80.55±0.45
# Epoch 15: TPCF=6063.0000±809.0300 ID=(np.float64(3.6184574353192716), np.float64(0.09311761460846833)) CosineSim=0.7003±0.1151 Anisotropy=0.1923 DaviesBouldin=1.3733 KNNAcc=79.86±0.53
# Epoch 16: TPCF=5427.6900±1768.6600 ID=(np.float64(3.6428425195549345), np.float64(0.07603042454505929)) CosineSim=0.7034±0.1143 Anisotropy=0.1968 DaviesBouldin=1.3542 KNNAcc=79.26±0.34
# Epoch 17: TPCF=6480.2200±1845.4400 ID=(np.float64(3.5559748111904903), np.float64(0.17416110294202627)) CosineSim=0.6876±0.1183 Anisotropy=0.1680 DaviesBouldin=1.3227 KNNAcc=79.73±0.23
# Epoch 18: TPCF=6614.9300±2463.9500 ID=(np.float64(3.747914243650875), np.float64(0.1057491411856286)) CosineSim=0.6801±0.1211 Anisotropy=0.1554 DaviesBouldin=1.2855 KNNAcc=80.95±0.27
# Epoch 19: TPCF=7648.7900±2239.5600 ID=(np.float64(3.7297595717695726), np.float64(0.050828028241258594)) CosineSim=0.6783±0.1208 Anisotropy=0.1644 DaviesBouldin=1.3492 KNNAcc=79.48±0.44
# Epoch 20: TPCF=6311.5900±1579.4400 ID=(np.float64(3.818409561064084), np.float64(0.09896040602478103)) CosineSim=0.6812±0.1204 Anisotropy=0.1855 DaviesBouldin=1.3452 KNNAcc=80.17±0.35
# Epoch 21: TPCF=8839.4800±3626.4300 ID=(np.float64(3.812525320791687), np.float64(0.07115050888225494)) CosineSim=0.6779±0.1211 Anisotropy=0.1724 DaviesBouldin=1.3630 KNNAcc=81.76±0.33
# Epoch 22: TPCF=8577.9900±2595.7000 ID=(np.float64(3.77505125744365), np.float64(0.05090688076301503)) CosineSim=0.6649±0.1260 Anisotropy=0.1812 DaviesBouldin=1.3339 KNNAcc=81.50±0.40
# Epoch 23: TPCF=8187.4600±1973.3600 ID=(np.float64(3.9383961637039975), np.float64(0.13321854608372813)) CosineSim=0.6622±0.1263 Anisotropy=0.1996 DaviesBouldin=1.3396 KNNAcc=79.88±0.25
# Epoch 24: TPCF=8214.5600±1457.8800 ID=(np.float64(3.857435458784953), np.float64(0.04701577060772595)) CosineSim=0.6515±0.1325 Anisotropy=0.1843 DaviesBouldin=1.3682 KNNAcc=81.05±0.35
# Epoch 25: TPCF=9225.1600±3182.1400 ID=(np.float64(3.7762059677007374), np.float64(0.043675066574147624)) CosineSim=0.6494±0.1331 Anisotropy=0.1852 DaviesBouldin=1.3401 KNNAcc=80.14±0.40
# Epoch 26: TPCF=10809.1000±3439.5800 ID=(np.float64(3.8781556314809955), np.float64(0.12825335631667137)) CosineSim=0.6511±0.1299 Anisotropy=0.1702 DaviesBouldin=1.3545 KNNAcc=79.62±0.29
# Epoch 27: TPCF=7412.4900±3628.1700 ID=(np.float64(3.931789341665077), np.float64(0.12200600209691204)) CosineSim=0.6447±0.1353 Anisotropy=0.1660 DaviesBouldin=1.3990 KNNAcc=79.88±0.38
# Epoch 28: TPCF=9730.3800±1638.4500 ID=(np.float64(4.085767654767389), np.float64(0.1299076664525344)) CosineSim=0.6416±0.1355 Anisotropy=0.2007 DaviesBouldin=1.3998 KNNAcc=80.27±0.42
# Epoch 29: TPCF=8696.4800±3234.1300 ID=(np.float64(3.815533899717343), np.float64(0.13284990105967276)) CosineSim=0.6286±0.1427 Anisotropy=0.1863 DaviesBouldin=1.4407 KNNAcc=79.25±0.31
# Epoch 30: TPCF=9825.9200±2971.5400 ID=(np.float64(4.045788479562272), np.float64(0.022704864841193162)) CosineSim=0.6651±0.1273 Anisotropy=0.1715 DaviesBouldin=1.5489 KNNAcc=78.77±0.17
# Epoch 31: TPCF=8254.7300±2413.5800 ID=(np.float64(4.028452581997953), np.float64(0.1633036712690821)) CosineSim=0.6427±0.1391 Anisotropy=0.1859 DaviesBouldin=1.5561 KNNAcc=78.75±0.57
# Epoch 32: TPCF=10114.0600±2265.6700 ID=(np.float64(4.049226962233273), np.float64(0.12247729903899972)) CosineSim=0.6365±0.1362 Anisotropy=0.1977 DaviesBouldin=1.3968 KNNAcc=79.82±0.26
# Epoch 33: TPCF=10159.6200±3947.2300 ID=(np.float64(4.542363999607095), np.float64(0.20271156825042833)) CosineSim=0.6129±0.1523 Anisotropy=0.1902 DaviesBouldin=1.6056 KNNAcc=78.39±0.11
# Epoch 34: TPCF=11764.5500±2592.6300 ID=(np.float64(4.212556379991142), np.float64(0.12060351146185155)) CosineSim=0.6137±0.1503 Anisotropy=0.1876 DaviesBouldin=1.4336 KNNAcc=79.54±0.28
# Epoch 35: TPCF=12728.4600±2787.0800 ID=(np.float64(4.427441268514901), np.float64(0.12431029131166922)) CosineSim=0.6041±0.1548 Anisotropy=0.1924 DaviesBouldin=1.4148 KNNAcc=80.88±0.33
# Epoch 36: TPCF=8174.4100±2680.7400 ID=(np.float64(4.665934571902784), np.float64(0.11892106234798686)) CosineSim=0.6076±0.1508 Anisotropy=0.1927 DaviesBouldin=1.3837 KNNAcc=79.78±0.17
# Epoch 37: TPCF=10260.8300±4654.0600 ID=(np.float64(4.798373760358783), np.float64(0.19195725470593758)) CosineSim=0.6019±0.1532 Anisotropy=0.1831 DaviesBouldin=1.3622 KNNAcc=80.42±0.24
# Epoch 38: TPCF=10203.1300±5512.4100 ID=(np.float64(4.81691389393467), np.float64(0.1659763782807401)) CosineSim=0.6061±0.1537 Anisotropy=0.1971 DaviesBouldin=1.4133 KNNAcc=80.23±0.41
# Epoch 39: TPCF=15069.8900±7251.9400 ID=(np.float64(3.9363208355002035), np.float64(0.12021380776370648)) CosineSim=0.6358±0.1348 Anisotropy=0.1672 DaviesBouldin=1.4055 KNNAcc=79.86±0.20
# Epoch 40: TPCF=13041.8900±7457.3400 ID=(np.float64(4.030899521459805), np.float64(0.19865010866822733)) CosineSim=0.6329±0.1372 Anisotropy=0.1642 DaviesBouldin=1.4048 KNNAcc=79.58±0.26
# Epoch 41: TPCF=16464.2600±7485.8700 ID=(np.float64(3.8306322728826045), np.float64(0.12672650842169175)) CosineSim=0.6337±0.1375 Anisotropy=0.1666 DaviesBouldin=1.4556 KNNAcc=79.61±0.47
# Epoch 42: TPCF=21017.2200±13870.2400 ID=(np.float64(4.005603595547724), np.float64(0.14574723862147287)) CosineSim=0.6313±0.1369 Anisotropy=0.1764 DaviesBouldin=1.4974 KNNAcc=79.77±0.34
# Epoch 43: TPCF=14526.4800±5604.1000 ID=(np.float64(3.896554758149289), np.float64(0.0734157995085239)) CosineSim=0.6229±0.1403 Anisotropy=0.1683 DaviesBouldin=1.5440 KNNAcc=79.03±0.32
# Epoch 44: TPCF=12638.4700±4934.5900 ID=(np.float64(4.116530394810566), np.float64(0.11878931286337498)) CosineSim=0.6322±0.1382 Anisotropy=0.1765 DaviesBouldin=1.4107 KNNAcc=80.09±0.26
# Epoch 45: TPCF=13263.1100±5631.6300 ID=(np.float64(3.8798443421683757), np.float64(0.13223976117171996)) CosineSim=0.6130±0.1453 Anisotropy=0.1809 DaviesBouldin=1.3230 KNNAcc=80.38±0.28
# Epoch 46: TPCF=11729.5900±6593.2600 ID=(np.float64(3.918944395479354), np.float64(0.17115188017199848)) CosineSim=0.6265±0.1418 Anisotropy=0.1969 DaviesBouldin=1.4501 KNNAcc=80.68±0.24
# Epoch 47: TPCF=12852.7100±3905.5400 ID=(np.float64(4.045507747607635), np.float64(0.14371607816508145)) CosineSim=0.6309±0.1401 Anisotropy=0.1797 DaviesBouldin=1.4494 KNNAcc=79.19±0.19
# Epoch 48: TPCF=20817.5800±5053.4700 ID=(np.float64(3.975279110793963), np.float64(0.0578403510112212)) CosineSim=0.6231±0.1413 Anisotropy=0.1653 DaviesBouldin=1.4855 KNNAcc=79.73±0.24
# Epoch 49: TPCF=11900.5400±5941.8500 ID=(np.float64(4.082954579460375), np.float64(0.12508157966396796)) CosineSim=0.6200±0.1422 Anisotropy=0.1617 DaviesBouldin=1.5395 KNNAcc=79.82±0.56
# Epoch 50: TPCF=9533.8400±3105.8200 ID=(np.float64(3.9003325094297003), np.float64(0.12397721833348666)) CosineSim=0.6196±0.1404 Anisotropy=0.1752 DaviesBouldin=1.3984 KNNAcc=80.30±0.26
# Epoch 51: TPCF=15567.4500±5829.0700 ID=(np.float64(3.8585581479603484), np.float64(0.08257624711558761)) CosineSim=0.6162±0.1439 Anisotropy=0.1813 DaviesBouldin=1.4224 KNNAcc=80.13±0.33
# Epoch 52: TPCF=16724.1900±7694.9200 ID=(np.float64(3.678211363312176), np.float64(0.12873325762260943)) CosineSim=0.6134±0.1423 Anisotropy=0.1715 DaviesBouldin=1.3869 KNNAcc=80.94±0.33
# Epoch 53: TPCF=15229.7100±5367.0300 ID=(np.float64(3.730424873006384), np.float64(0.08139775333811923)) CosineSim=0.6107±0.1462 Anisotropy=0.1687 DaviesBouldin=1.4463 KNNAcc=79.15±0.43
# Epoch 54: TPCF=13788.8700±7160.9700 ID=(np.float64(4.0277206952416575), np.float64(0.17683499740636882)) CosineSim=0.6120±0.1442 Anisotropy=0.1746 DaviesBouldin=1.4292 KNNAcc=79.06±0.35
# Epoch 55: TPCF=16907.1700±5634.5800 ID=(np.float64(3.948691234842156), np.float64(0.0414039186420585)) CosineSim=0.6196±0.1407 Anisotropy=0.1958 DaviesBouldin=1.4360 KNNAcc=80.31±0.30
# Epoch 56: TPCF=13928.9400±3798.9200 ID=(np.float64(3.864673156794212), np.float64(0.09504114666146544)) CosineSim=0.6104±0.1460 Anisotropy=0.1741 DaviesBouldin=1.3768 KNNAcc=79.71±0.35
# Epoch 57: TPCF=10427.0800±7003.7600 ID=(np.float64(3.8893126041540875), np.float64(0.10280813650444878)) CosineSim=0.6049±0.1462 Anisotropy=0.1769 DaviesBouldin=1.3849 KNNAcc=79.72±0.32
# Epoch 58: TPCF=16310.7400±9136.4200 ID=(np.float64(3.8460924185500796), np.float64(0.08296800923465857)) CosineSim=0.6065±0.1461 Anisotropy=0.1822 DaviesBouldin=1.3506 KNNAcc=80.20±0.17
# Epoch 59: TPCF=18991.5400±9688.7300 ID=(np.float64(3.8964887895355105), np.float64(0.18749567854992535)) CosineSim=0.6160±0.1426 Anisotropy=0.1792 DaviesBouldin=1.4154 KNNAcc=79.49±0.30
# Epoch 60: TPCF=15394.1800±9600.0000 ID=(np.float64(4.010785950051812), np.float64(0.12003025696795395)) CosineSim=0.6212±0.1416 Anisotropy=0.1729 DaviesBouldin=1.5222 KNNAcc=79.67±0.22
# Epoch 61: TPCF=9898.9800±2429.5700 ID=(np.float64(3.9012902680858517), np.float64(0.09572984018351505)) CosineSim=0.6080±0.1432 Anisotropy=0.1716 DaviesBouldin=1.4431 KNNAcc=78.84±0.25
# Epoch 62: TPCF=16267.4100±6309.5700 ID=(np.float64(3.7938750265897028), np.float64(0.09692790505395776)) CosineSim=0.5946±0.1537 Anisotropy=0.1953 DaviesBouldin=1.4456 KNNAcc=79.79±0.24
# Epoch 63: TPCF=18034.8200±9719.3700 ID=(np.float64(3.9599608670461612), np.float64(0.046572991735875605)) CosineSim=0.5999±0.1491 Anisotropy=0.1717 DaviesBouldin=1.3999 KNNAcc=79.34±0.32
# Epoch 64: TPCF=17353.3000±7684.8300 ID=(np.float64(4.152200535626418), np.float64(0.11021548013458629)) CosineSim=0.5983±0.1506 Anisotropy=0.1827 DaviesBouldin=1.4274 KNNAcc=79.25±0.26
# Epoch 65: TPCF=16971.2200±6555.9300 ID=(np.float64(3.8432526963114753), np.float64(0.08062504308113616)) CosineSim=0.6004±0.1510 Anisotropy=0.1972 DaviesBouldin=1.5150 KNNAcc=78.65±0.20
# Epoch 66: TPCF=14716.7100±4911.8700 ID=(np.float64(4.012308016517002), np.float64(0.0598393938676765)) CosineSim=0.5953±0.1501 Anisotropy=0.1724 DaviesBouldin=1.4309 KNNAcc=78.84±0.35
# Epoch 67: TPCF=15903.6900±4857.1800 ID=(np.float64(4.011311495892471), np.float64(0.1276972662771656)) CosineSim=0.5950±0.1517 Anisotropy=0.1817 DaviesBouldin=1.3688 KNNAcc=78.79±0.34
# Epoch 68: TPCF=13411.5100±6704.0400 ID=(np.float64(4.1459805961808565), np.float64(0.14492151183837446)) CosineSim=0.5987±0.1493 Anisotropy=0.1645 DaviesBouldin=1.3759 KNNAcc=79.69±0.43
# Epoch 69: TPCF=20623.1100±4304.4200 ID=(np.float64(4.108441146076599), np.float64(0.10557887437858286)) CosineSim=0.5971±0.1493 Anisotropy=0.1800 DaviesBouldin=1.3631 KNNAcc=79.65±0.13
# Epoch 70: TPCF=16044.7500±5664.2200 ID=(np.float64(4.202599607602629), np.float64(0.060520804140470036)) CosineSim=0.5936±0.1508 Anisotropy=0.1750 DaviesBouldin=1.4514 KNNAcc=80.11±0.27
# Epoch 71: TPCF=18458.2400±10886.8900 ID=(np.float64(4.013429365433879), np.float64(0.10974546167950619)) CosineSim=0.5924±0.1553 Anisotropy=0.1769 DaviesBouldin=1.4590 KNNAcc=79.86±0.34
# Epoch 72: TPCF=16547.5200±9280.2000 ID=(np.float64(4.094935486005318), np.float64(0.10675050000554495)) CosineSim=0.5997±0.1523 Anisotropy=0.1936 DaviesBouldin=1.6013 KNNAcc=78.37±0.31
# Epoch 73: TPCF=15522.1800±5835.0700 ID=(np.float64(4.027545162405471), np.float64(0.08539385053106337)) CosineSim=0.5918±0.1544 Anisotropy=0.1791 DaviesBouldin=1.4409 KNNAcc=78.69±0.27
# Epoch 74: TPCF=20250.2200±5538.0700 ID=(np.float64(4.1097437776499515), np.float64(0.1339530639336482)) CosineSim=0.5832±0.1600 Anisotropy=0.2072 DaviesBouldin=1.4881 KNNAcc=79.87±0.33
# Epoch 75: TPCF=15419.5700±7561.9000 ID=(np.float64(4.103724055837077), np.float64(0.16677231200407863)) CosineSim=0.5861±0.1574 Anisotropy=0.1878 DaviesBouldin=1.4290 KNNAcc=79.70±0.20
# Epoch 76: TPCF=19860.7800±14347.7100 ID=(np.float64(4.248702597111869), np.float64(0.13435452535033857)) CosineSim=0.5910±0.1553 Anisotropy=0.2042 DaviesBouldin=1.4423 KNNAcc=79.80±0.27
# Epoch 77: TPCF=13382.5100±6389.6100 ID=(np.float64(4.019778680141115), np.float64(0.11145811579578846)) CosineSim=0.5808±0.1556 Anisotropy=0.1739 DaviesBouldin=1.4112 KNNAcc=78.62±0.29
# Epoch 78: TPCF=20799.1400±12718.2900 ID=(np.float64(4.0779446315453525), np.float64(0.10900543130436337)) CosineSim=0.5976±0.1588 Anisotropy=0.2115 DaviesBouldin=1.5656 KNNAcc=79.94±0.21
# Epoch 79: TPCF=21548.0800±6254.5700 ID=(np.float64(4.042976470327999), np.float64(0.08617465590276481)) CosineSim=0.5821±0.1594 Anisotropy=0.2061 DaviesBouldin=1.4303 KNNAcc=79.49±0.21
# Epoch 80: TPCF=13297.8700±2227.9800 ID=(np.float64(4.163963419621218), np.float64(0.16119071820431216)) CosineSim=0.5847±0.1560 Anisotropy=0.1938 DaviesBouldin=1.3543 KNNAcc=79.08±0.26
# Epoch 81: TPCF=15505.2400±5601.8900 ID=(np.float64(4.263889996388268), np.float64(0.07375060432143193)) CosineSim=0.5828±0.1569 Anisotropy=0.1984 DaviesBouldin=1.4913 KNNAcc=79.29±0.23
# Epoch 82: TPCF=19637.0800±4971.8900 ID=(np.float64(3.8593999751701027), np.float64(0.10039514260669487)) CosineSim=0.5767±0.1606 Anisotropy=0.1858 DaviesBouldin=1.5028 KNNAcc=79.52±0.21
# Epoch 83: TPCF=18937.1600±4660.9800 ID=(np.float64(4.100636563238785), np.float64(0.14714404589971508)) CosineSim=0.5966±0.1548 Anisotropy=0.1902 DaviesBouldin=1.4287 KNNAcc=79.22±0.20
# Epoch 84: TPCF=24804.1800±7612.8500 ID=(np.float64(4.394731877704706), np.float64(0.12103071587994382)) CosineSim=0.5834±0.1583 Anisotropy=0.1842 DaviesBouldin=1.5810 KNNAcc=80.26±0.28
# Epoch 85: TPCF=16843.4400±3173.3700 ID=(np.float64(4.104889094843715), np.float64(0.06130470666601946)) CosineSim=0.5904±0.1562 Anisotropy=0.1811 DaviesBouldin=1.4637 KNNAcc=79.45±0.31
# Epoch 86: TPCF=20876.0300±9991.7400 ID=(np.float64(4.296819221334165), np.float64(0.08638080271413012)) CosineSim=0.5885±0.1596 Anisotropy=0.2133 DaviesBouldin=1.4560 KNNAcc=78.35±0.35
# Epoch 87: TPCF=10932.7300±3144.9300 ID=(np.float64(4.3291238164409815), np.float64(0.14564367389674834)) CosineSim=0.5806±0.1578 Anisotropy=0.1939 DaviesBouldin=1.4867 KNNAcc=79.78±0.24
# Epoch 88: TPCF=12419.2600±6049.3500 ID=(np.float64(4.211336845575451), np.float64(0.1246753178611364)) CosineSim=0.5807±0.1577 Anisotropy=0.1952 DaviesBouldin=1.5283 KNNAcc=78.42±0.32
# Epoch 89: TPCF=10251.5200±3620.0700 ID=(np.float64(4.325624241208556), np.float64(0.15240735666350125)) CosineSim=0.5728±0.1603 Anisotropy=0.1811 DaviesBouldin=1.4706 KNNAcc=79.21±0.32
# Epoch 90: TPCF=14506.0200±6716.2000 ID=(np.float64(4.3699357748711325), np.float64(0.037766019801045075)) CosineSim=0.5856±0.1570 Anisotropy=0.1764 DaviesBouldin=1.4876 KNNAcc=79.13±0.34
# Epoch 91: TPCF=14390.5400±3828.8000 ID=(np.float64(4.210159206655993), np.float64(0.15500473415840024)) CosineSim=0.5761±0.1589 Anisotropy=0.2038 DaviesBouldin=1.4889 KNNAcc=78.90±0.28
# Epoch 92: TPCF=14648.5500±4341.6200 ID=(np.float64(4.53708404407816), np.float64(0.08508559630513488)) CosineSim=0.5812±0.1595 Anisotropy=0.2218 DaviesBouldin=1.4652 KNNAcc=78.89±0.32
# Epoch 93: TPCF=16321.7000±10841.7500 ID=(np.float64(4.41510650356866), np.float64(0.13265724384707708)) CosineSim=0.5815±0.1603 Anisotropy=0.1995 DaviesBouldin=1.4653 KNNAcc=79.45±0.24
# Epoch 94: TPCF=17871.4000±9229.9100 ID=(np.float64(4.317349569285785), np.float64(0.13792998004090454)) CosineSim=0.5776±0.1597 Anisotropy=0.1957 DaviesBouldin=1.4758 KNNAcc=79.36±0.27
# Epoch 95: TPCF=20658.4300±7934.1100 ID=(np.float64(4.23899930805162), np.float64(0.06843971363657739)) CosineSim=0.5844±0.1559 Anisotropy=0.1907 DaviesBouldin=1.4202 KNNAcc=78.78±0.26
# Epoch 96: TPCF=17488.7400±8743.2100 ID=(np.float64(4.581932876941981), np.float64(0.19341993811475353)) CosineSim=0.5934±0.1588 Anisotropy=0.1919 DaviesBouldin=1.5749 KNNAcc=78.25±0.31
# Epoch 97: TPCF=11216.9200±6931.4000 ID=(np.float64(4.118890622171294), np.float64(0.11405349507270911)) CosineSim=0.5853±0.1579 Anisotropy=0.1903 DaviesBouldin=1.3340 KNNAcc=79.25±0.34
# Epoch 98: TPCF=15244.0200±6555.9300 ID=(np.float64(4.124972820032849), np.float64(0.13631901158433246)) CosineSim=0.5739±0.1615 Anisotropy=0.1977 DaviesBouldin=1.3706 KNNAcc=79.77±0.31
# Epoch 99: TPCF=20406.0300±8369.2700 ID=(np.float64(4.504208822910511), np.float64(0.1365751831596319)) CosineSim=0.5803±0.1596 Anisotropy=0.1955 DaviesBouldin=1.4248 KNNAcc=79.19±0.30

# %%
results = pd.DataFrame({
    "epoch": range(n_epochs),
    "tpcf_score": tpcf_scores,
    "tpcf_std": tpcf_std_scores,
    "id_mean": [i[0] for i in id_scores],
    "id_std": [i[1] for i in id_scores],
    "avg_cosine_similarity": cosine_sim_scores,
    "cosine_similarity_std": cosine_sim_std_scores,
    "anisotropy": anisotropy_scores,
    "davies_bouldin": davies_bouldin_scores,
    "knn_accuracy": knn_accuracy_scores,
    "knn_accuracy_std": knn_accuracy_std_scores,
})

# keep pickle format for compatibility with existing plotting notebooks
with open("Test_TPCF_score.csv", "wb") as file:
    pickle.dump(tpcf_scores, file)

with open("Test_id_score.csv", "wb") as file:
    pickle.dump(id_scores, file)

results.to_csv("Test_TPCF_id_scores.csv", index=False)
results
# Out:
#     epoch  tpcf_score  tpcf_std    id_mean    id_std  avg_cosine_similarity  \
# 0       0      568.21    330.37  52.743261  1.631595               0.195290
# 1       1     6038.66   1038.99   6.493028  0.252176               0.813158
# 2       2     9338.34   3740.32   5.599404  0.138679               0.773033
# 3       3     5069.41   1363.36   5.148120  0.212332               0.764261
# 4       4     6203.88   2427.55   4.812330  0.085472               0.754089
# ..    ...         ...       ...        ...       ...                    ...
# 95     95    20658.43   7934.11   4.238999  0.068440               0.584419
# 96     96    17488.74   8743.21   4.581933  0.193420               0.593364
# 97     97    11216.92   6931.40   4.118891  0.114053               0.585264
# 98     98    15244.02   6555.93   4.124973  0.136319               0.573901
# 99     99    20406.03   8369.27   4.504209  0.136575               0.580254
#
#     cosine_similarity_std  anisotropy  davies_bouldin  knn_accuracy  \
# 0                0.120019    0.968971       12.242701         20.16
# 1                0.105050    0.993488        3.340510         56.97
# 2                0.100912    0.193982        2.108989         69.77
# 3                0.100155    0.204972        1.955844         74.45
# 4                0.099601    0.197458        1.474272         76.55
# ..                    ...         ...             ...           ...
# 95               0.155873    0.190735        1.420186         78.78
# 96               0.158794    0.191867        1.574932         78.25
# 97               0.157886    0.190268        1.334020         79.25
# 98               0.161525    0.197656        1.370631         79.77
# 99               0.159637    0.195544        1.424810         79.19
#
#     knn_accuracy_std
# 0               0.43
# 1               0.52
# 2               0.51
# 3               0.28
# 4               0.29
# ..               ...
# 95              0.26
# 96              0.31
# 97              0.34
# 98              0.31
# 99              0.30
#
# [100 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import string

plt.rcParams.update({
    "figure.dpi": 300,
    "savefig.dpi": 300,
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "mathtext.fontset": "stix",
    "font.size": 11,
    "axes.labelsize": 12,
    "axes.titlesize": 12,
    "axes.linewidth": 0.8,
    "axes.grid": True,
    "grid.alpha": 0.3,
    "grid.linewidth": 0.5,
    "lines.linewidth": 1.5,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.minor.visible": True,
    "ytick.minor.visible": True,
    "xtick.top": True,
    "ytick.right": True,
    "legend.frameon": False,
})

ACCENT = "#1f4e79"

metrics = [
    ("tpcf_score", "TPCF score", "tpcf_std"),
    ("id_mean", "Intrinsic dimension", "id_std"),
    ("avg_cosine_similarity", "Avg. cosine similarity", "cosine_similarity_std"),
    ("cosine_similarity_std", "Cosine similarity std", None),
    ("anisotropy", "Anisotropy (top-1 EVR)", None),
    ("davies_bouldin", "Davies-Bouldin score", None),
    ("knn_accuracy", "KNN accuracy (%)", "knn_accuracy_std"),
]


def plot_gradient_band(ax, x, y, y_err, color=ACCENT, n_layers=40, max_sigma=3.0):
    """Shade the uncertainty band with an alpha gradient that fades away from the mean."""
    x = np.asarray(x)
    y = np.asarray(y)
    y_err = np.asarray(y_err)
    sigmas = np.linspace(max_sigma / n_layers, max_sigma, n_layers)
    for sigma in sigmas[::-1]:
        alpha = 0.35 * np.exp(-0.5 * sigma ** 2)
        ax.fill_between(x, y - sigma * y_err, y + sigma * y_err, color=color, alpha=alpha, linewidth=0)


n_cols = 3
n_rows = -(-len(metrics) // n_cols)  # ceil division

fig, axes = plt.subplots(
    n_rows, n_cols, figsize=(3.3 * n_cols, 2.5 * n_rows), squeeze=False, constrained_layout=True
)
axes = axes.flatten()

for panel_label, ax, (col, title, err_col) in zip(string.ascii_lowercase, axes, metrics):
    ax.plot(results["epoch"], results[col], color=ACCENT)
    if col == "tpcf_score":
        plot_gradient_band(ax, results["epoch"], results[col], results[err_col])
    elif err_col is not None:
        ax.fill_between(
            results["epoch"],
            results[col] - results[err_col],
            results[col] + results[err_col],
            color=ACCENT,
            alpha=0.2,
        )
    ax.set_title(title)
    ax.set_xlabel("Epoch")
    ax.set_ylabel(title)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.text(-0.15, 1.08, f"({panel_label})", transform=ax.transAxes, fontsize=11, fontweight="bold")

# hide any unused axes in the grid
for ax in axes[len(metrics):]:
    ax.axis("off")

fig.savefig("Test_metrics_grid.pdf", bbox_inches="tight")
fig.savefig("Test_metrics_grid.png", bbox_inches="tight")
plt.show()
